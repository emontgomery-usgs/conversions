# %%
import netCDF4 as nc
from netCDF4 import Dataset
import glob
import thredds_crawler
from thredds_crawler.crawl import Crawl

# %%
# getting metadata will work with explicit reference to a file on TDS
fname='http://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/MVCO_15/105710mc-a.nc'
fnc=nc.Dataset(fname,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
m_att=fnc.getncattr('MOORING')
print(fname)
print(" ".join([": MOORING att is: ", m_att]))
fnc.close()

# %%
# play with ncattrs to get all global atts instead of just the ones we want using 3 calls
fname='http://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/MVCO_15/105710mc-a.nc'
fnc=nc.Dataset(fname,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
#all_atts=fnc.ncattrs()  # this just makes a list of all attribute names, not a dict of their values
all_atts=fnc.__dict__
#type(all_atts)
print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
fnc.close()

# %%
# looping works- if it's alocal path 
fpath="C:/home/data/validation/GrandBay/candidate_final_files/"
# but not if I point to a TDS location, even though above, fname with the URL worked OK
#fpath="http://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/MVCO_15/"

for filename in glob.glob(fpath + '*.nc'):
        #print(filename)
        fnc=nc.Dataset(filename,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
        m_att=fnc.getncattr('MOORING')
        inst=fnc.getncattr('INST_TYPE')
        sn=fnc.getncattr('serial_number')
        print(" ".join(["MOORING ", m_att, "has INST is ", inst, " SN is ",sn]))
        fnc.close()

# %%
# you need to have imported Kyle's thredds crawler for this
# this works great on the GRANDBAY catalog, but not on MVCO_15 or Sandwich2016
fpath="https://stellwagen.er.usgs.gov/thredds/catalog/TSdata/GRANDBAY/catalog.xml"
c = Crawl(fpath, select=[".*nc"])
#print (c.datasets)

# %%
#c.datasets

# %%
urls = [s.get("url") for d in c.datasets for s in d.services if s.get("service").lower() == "opendap"]
for fn in urls:
    print(fn)
    fnc=nc.Dataset(fn,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
    all_atts=fnc.__dict__  # get all the global atts and their values as a dict
    print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
    fnc.close()

# %%
del c

# %%
#Since this worked great on the GRANDBAY catalog, why won't it work on MVCO 15 or Sandwich2016
fpath="https://stellwagen.er.usgs.gov/thredds/catalog/TSdata/SANDWICH2016/catalog.xml"
c = Crawl(fpath, select=[".*nc"])

# %%
#c.datasets

# %%
urls = [s.get("url") for d in c.datasets for s in d.services if s.get("service").lower() == "opendap"]

# %%
for fn in urls:
    print(fn)
    if type(fn) is str:
        fnc=nc.Dataset(fn,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
    else:
        fnc=nc.Dataset(str(fn))
    all_atts=fnc.__dict__  # get all the global atts and their values as a dict
    print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
    fnc.close()
# Out:
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10591dw-a.nc
# mooring  1059 : there is a  RBR Virtuouso D|wave ; SN  055025
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10591dwvs-cal.nc
# mooring  1059 : there is a  RBR Virtuouso D|wave ; SN  055025
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10601hwlb-a.nc
# mooring  10601 : there is a  Hobo pressure logger ; SN  10313354
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10602dw-a.nc
# mooring  1060 : there is a  RBR Solo ; SN  077669
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10612dw-a.nc
# mooring  1061 : there is a  RBR Solo ; SN  077827
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10622dw-a.nc
# mooring  1062 : there is a  RBR Solo ; SN  077828
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-a.nc
# mooring  1063 : there is a  TRDI V ; SN  20784.0
# https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-fa66b3b63339> in <module>
#       2     print(fn)
#       3     if type(fn) is str:
# ----> 4         fnc=nc.Dataset(fn,mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
#       5     else:
#       6         fnc=nc.Dataset(str(fn))
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -36] NetCDF: Invalid argument: b'https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'

# %%
#This is the problem file in MVCO15- why is it being automagically turned into a byte?
#fn='https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/MVCO_15/10571whV-a.nc'
fn='https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'
# it looks like casting to a string works for the MVCO file but not the Sandwhich one...
fnc=nc.Dataset(str(fn),mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
all_atts=fnc.__dict__  # get all the global atts and their values as a dict
print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
fnc.close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-c14d677c76e6> in <module>
#       3 fn='https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'
#       4 # it looks like this name has to be cast to a string...
# ----> 5 fnc=nc.Dataset(str(fn),mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
#       6 all_atts=fnc.__dict__  # get all the global atts and their values as a dict
#       7 print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -36] NetCDF: Invalid argument: b'https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'

# %%
# !ncdump -h https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/MVCO_15/10571whV-a.nc
# Out:
# netcdf \10571whV-a {
# dimensions:
# 	time = UNLIMITED ; // (1294 currently)
# 	depth = 66 ;
# 	lat = 1 ;
# 	lon = 1 ;
# variables:
# 	int time(time) ;
# 		time:FORTRAN_format = "F10.2" ;
# 		time:units = "True Julian Day" ;
# 		time:type = "UNEVEN" ;
# 		time:epic_code = 624. ;
# 		time:datum = "Time (UTC) in True Julian Days: 2440000 = 0000 h on May 23, 1968" ;
# 		time:NOTE = "Decimal Julian day [days] = time [days] + ( time2 [msec] / 86400000 [msec/day] )" ;
# 	int time2(time) ;
# 		time2:FORTRAN_format = "F10.2" ;
# 		time2:units = "msec since 0:00 GMT" ;
# 		time2:type = "UNEVEN" ;
# 		time2:epic_code = 624. ;
# 		time2:datum = "Time (UTC) in True Julian Days: 2440000 = 0000 h on May 23, 1968" ;
# 		time2:NOTE = "Decimal Julian day [days] = time [days] + ( time2 [msec] / 86400000 [msec/day] )" ;
# 	float depth(depth) ;
# 		depth:units = "m" ;
# 		depth:long_name = "DEPTH (M)" ;
# 		depth:FORTRAN_format = " " ;
# 		depth:epic_code = 3. ;
# 		depth:type = "EVEN" ;
# 		depth:center_first_bin = 0.84 ;
# 		depth:blanking_distance = 0.4 ;
# 		depth:bin_size = 0.3 ;
# 		depth:bin_count = 66. ;
# 		depth:WATER_DEPTH = 0. ;
# 		depth:WATER_DEPTH_source = "water_depth information not provided to rdi2cdf" ;
# 		depth:WATER_DEPTH_datum = "not yet assigned" ;
# 		depth:transducer_offset_from_bottom = 2.4 ;
# 	float lat(lat) ;
# 		lat:FORTRAN_format = "F10.2" ;
# 		lat:units = "degree_north" ;
# 		lat:type = "EVEN" ;
# 		lat:epic_code = 500. ;
# 		lat:name = "LAT" ;
# 		lat:long_name = "LATITUDE" ;
# 		lat:generic_name = "lat" ;
# 		lat:datum = "NAD83" ;
# 	float lon(lon) ;
# 		lon:FORTRAN_format = "F10.2" ;
# 		lon:units = "degree_east" ;
# 		lon:type = "EVEN" ;
# 		lon:epic_code = 502. ;
# 		lon:name = "LON" ;
# 		lon:long_name = "LONGITUDE" ;
# 		lon:generic_name = "lon" ;
# 		lon:datum = "NAD83" ;
# 	float bindist(depth) ;
# 		bindist:name = "bindist" ;
# 		bindist:units = "cm/s" ;
# 		bindist:type = "EVEN" ;
# 		bindist:long_name = "bin distance from instrument (m)" ;
# 		bindist:generic_name = "bindist" ;
# 		bindist:epic_code = 0. ;
# 		bindist:valid_range = " " ;
# 		bindist:center_first_bin = 0.84 ;
# 		bindist:blanking_distance = 0.4 ;
# 		bindist:bin_size = 0.3 ;
# 		bindist:bin_count = 66. ;
# 		bindist:WATER_DEPTH = 13.8440029710665 ;
# 		bindist:WATER_DEPTH_source = "water depth = MSL from pressure sensor" ;
# 		bindist:WATER_DEPTH_datum = "MSL" ;
# 		bindist:transducer_offset_from_bottom = 2.4 ;
# 		bindist:NOTE = "distance is along profile from instrument head to center of bin" ;
# 		bindist:minimum = 0.84f ;
# 		bindist:maximum = 20.34f ;
# 	float u_1205(time, depth, lat, lon) ;
# 		u_1205:name = "u" ;
# 		u_1205:long_name = "Eastward Velocity" ;
# 		u_1205:generic_name = "u" ;
# 		u_1205:units = "cm/s" ;
# 		u_1205:epic_code = 1205. ;
# 		u_1205:valid_range = " " ;
# 		u_1205:minimum = -78.78294f ;
# 		u_1205:maximum = 63.79893f ;
# 		u_1205:sensor_type = "TRDI V" ;
# 		u_1205:sensor_depth = 11.4440029710665 ;
# 		u_1205:initial_sensor_height = 2.4 ;
# 		u_1205:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		u_1205:height_depth_units = "m" ;
# 		u_1205:serial_number = 23881. ;
# 		u_1205:_FillValue = 1.e+35f ;
# 	float v_1206(time, depth, lat, lon) ;
# 		v_1206:name = "v" ;
# 		v_1206:long_name = "Northward Velocity" ;
# 		v_1206:generic_name = "v" ;
# 		v_1206:units = "cm/s" ;
# 		v_1206:epic_code = 1206. ;
# 		v_1206:valid_range = " " ;
# 		v_1206:minimum = -56.49777f ;
# 		v_1206:maximum = 50.10242f ;
# 		v_1206:sensor_type = "TRDI V" ;
# 		v_1206:sensor_depth = 11.4440029710665 ;
# 		v_1206:initial_sensor_height = 2.4 ;
# 		v_1206:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		v_1206:height_depth_units = "m" ;
# 		v_1206:serial_number = 23881. ;
# 		v_1206:_FillValue = 1.e+35f ;
# 	float w_1204(time, depth, lat, lon) ;
# 		w_1204:name = "w" ;
# 		w_1204:long_name = "Vertical Velocity" ;
# 		w_1204:generic_name = "w" ;
# 		w_1204:units = "cm/s" ;
# 		w_1204:epic_code = 1204. ;
# 		w_1204:valid_range = 0., 100. ;
# 		w_1204:NOTE = "From the center vertical beam" ;
# 		w_1204:minimum = -2.800687f ;
# 		w_1204:maximum = 4.000394f ;
# 		w_1204:sensor_type = "TRDI V" ;
# 		w_1204:sensor_depth = 11.4440029710665 ;
# 		w_1204:initial_sensor_height = 2.4 ;
# 		w_1204:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		w_1204:height_depth_units = "m" ;
# 		w_1204:serial_number = 23881. ;
# 		w_1204:_FillValue = 1.e+35f ;
# 	float Werr_1201(time, depth, lat, lon) ;
# 		Werr_1201:name = "Werr" ;
# 		Werr_1201:long_name = "Error Velocity" ;
# 		Werr_1201:generic_name = "Werr" ;
# 		Werr_1201:units = "cm/s" ;
# 		Werr_1201:epic_code = 1204. ;
# 		Werr_1201:valid_range = 0., 100. ;
# 		Werr_1201:NOTE = "Calculated from the slant beams" ;
# 		Werr_1201:minimum = -11.00235f ;
# 		Werr_1201:maximum = 12.2012f ;
# 		Werr_1201:sensor_type = "TRDI V" ;
# 		Werr_1201:sensor_depth = 11.4440029710665 ;
# 		Werr_1201:initial_sensor_height = 2.4 ;
# 		Werr_1201:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Werr_1201:height_depth_units = "m" ;
# 		Werr_1201:serial_number = 23881. ;
# 		Werr_1201:_FillValue = 1.e+35f ;
# 	float Wvert(time, depth, lat, lon) ;
# 		Wvert:name = "Wvert" ;
# 		Wvert:long_name = "Vertical Beam Velocity" ;
# 		Wvert:generic_name = "Wvert" ;
# 		Wvert:units = "cm/s" ;
# 		Wvert:epic_code = 1204. ;
# 		Wvert:valid_range = 0., 100. ;
# 		Wvert:minimum = -5.10006f ;
# 		Wvert:maximum = 3.300075f ;
# 		Wvert:sensor_type = "TRDI V" ;
# 		Wvert:sensor_depth = 11.4440029710665 ;
# 		Wvert:initial_sensor_height = 2.4 ;
# 		Wvert:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Wvert:height_depth_units = "m" ;
# 		Wvert:serial_number = 23881. ;
# 		Wvert:_FillValue = 1.e+35f ;
# 	float AGC_1202(time, depth, lat, lon) ;
# 		AGC_1202:name = "cor" ;
# 		AGC_1202:long_name = "Slant Beam Average Corellation (cor)" ;
# 		AGC_1202:generic_name = "cor" ;
# 		AGC_1202:units = "counts" ;
# 		AGC_1202:epic_code = 1202. ;
# 		AGC_1202:valid_range = 0., 255. ;
# 		AGC_1202:minimum = 36.75f ;
# 		AGC_1202:maximum = 182.f ;
# 		AGC_1202:sensor_type = "TRDI V" ;
# 		AGC_1202:sensor_depth = 11.4440029710665 ;
# 		AGC_1202:initial_sensor_height = 2.4 ;
# 		AGC_1202:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		AGC_1202:height_depth_units = "m" ;
# 		AGC_1202:serial_number = 23881. ;
# 		AGC_1202:_FillValue = 1.e+35f ;
# 	float AGCvert(time, depth, lat, lon) ;
# 		AGCvert:name = "AGCvert" ;
# 		AGCvert:long_name = "Vertical Beam Echo Intensity (AGC)" ;
# 		AGCvert:generic_name = "AGCvert" ;
# 		AGCvert:units = "counts" ;
# 		AGCvert:epic_code = 1202. ;
# 		AGCvert:minimum = 38.f ;
# 		AGCvert:maximum = 254.f ;
# 		AGCvert:sensor_type = "TRDI V" ;
# 		AGCvert:sensor_depth = 11.4440029710665 ;
# 		AGCvert:initial_sensor_height = 2.4 ;
# 		AGCvert:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		AGCvert:height_depth_units = "m" ;
# 		AGCvert:serial_number = 23881. ;
# 		AGCvert:_FillValue = 1.e+35f ;
# 	float cor(time, depth, lat, lon) ;
# 		cor:minimum = 58.75f ;
# 		cor:maximum = 144.5f ;
# 		cor:sensor_type = "TRDI V" ;
# 		cor:sensor_depth = 11.4440029710665 ;
# 		cor:initial_sensor_height = 2.4 ;
# 		cor:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		cor:height_depth_units = "m" ;
# 		cor:serial_number = 23881. ;
# 		cor:_FillValue = 1.e+35f ;
# 	float corvert(time, depth, lat, lon) ;
# 		corvert:name = "cor" ;
# 		corvert:long_name = "Vertical Beam Corellation (cor)" ;
# 		corvert:generic_name = "cor" ;
# 		corvert:units = "counts" ;
# 		corvert:epic_code = 1202. ;
# 		corvert:valid_range = 0., 255. ;
# 		corvert:minimum = 18.f ;
# 		corvert:maximum = 163.f ;
# 		corvert:sensor_type = "TRDI V" ;
# 		corvert:sensor_depth = 11.4440029710665 ;
# 		corvert:initial_sensor_height = 2.4 ;
# 		corvert:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		corvert:height_depth_units = "m" ;
# 		corvert:serial_number = 23881. ;
# 		corvert:_FillValue = 1.e+35f ;
# 	float PGd_1203(time, depth, lat, lon) ;
# 		PGd_1203:name = "PGd" ;
# 		PGd_1203:long_name = "Percent Good Pings" ;
# 		PGd_1203:generic_name = "PGd" ;
# 		PGd_1203:units = "percent" ;
# 		PGd_1203:epic_code = 1203. ;
# 		PGd_1203:NOTE = "Percentage of good 4-beam solutions (Field #4)" ;
# 		PGd_1203:minimum = 0.f ;
# 		PGd_1203:maximum = 100.f ;
# 		PGd_1203:sensor_type = "TRDI V" ;
# 		PGd_1203:sensor_depth = 11.4440029710665 ;
# 		PGd_1203:initial_sensor_height = 2.4 ;
# 		PGd_1203:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		PGd_1203:height_depth_units = "m" ;
# 		PGd_1203:serial_number = 23881. ;
# 		PGd_1203:_FillValue = 1.e+35f ;
# 	float Tx_1211(time, lat, lon) ;
# 		Tx_1211:units = "C" ;
# 		Tx_1211:type = "EVEN" ;
# 		Tx_1211:epic_code = 1211. ;
# 		Tx_1211:name = "T" ;
# 		Tx_1211:long_name = "instrument Transducer Temp." ;
# 		Tx_1211:generic_name = "temp" ;
# 		Tx_1211:valid_range = 0., 40. ;
# 		Tx_1211:minimum = 8.949175f ;
# 		Tx_1211:maximum = 12.62367f ;
# 		Tx_1211:sensor_type = "TRDI V" ;
# 		Tx_1211:sensor_depth = 11.4440029710665 ;
# 		Tx_1211:initial_sensor_height = 2.4 ;
# 		Tx_1211:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Tx_1211:height_depth_units = "m" ;
# 		Tx_1211:serial_number = 23881. ;
# 		Tx_1211:_FillValue = 1.e+35f ;
# 	float SV_80(time, lat, lon) ;
# 		SV_80:units = "m s-1" ;
# 		SV_80:type = "EVEN" ;
# 		SV_80:epic_code = 80. ;
# 		SV_80:name = "SV" ;
# 		SV_80:long_name = "SOUND VELOCITY (M/S)" ;
# 		SV_80:generic_name = " " ;
# 		SV_80:valid_range = 1400., 1600. ;
# 		SV_80:minimum = 1482.598f ;
# 		SV_80:maximum = 1495.622f ;
# 		SV_80:sensor_type = "TRDI V" ;
# 		SV_80:sensor_depth = 11.4440029710665 ;
# 		SV_80:initial_sensor_height = 2.4 ;
# 		SV_80:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		SV_80:height_depth_units = "m" ;
# 		SV_80:serial_number = 23881. ;
# 		SV_80:_FillValue = 1.e+35f ;
# 	float Hdg_1215(time, lat, lon) ;
# 		Hdg_1215:name = "Hdg" ;
# 		Hdg_1215:long_name = "INST Heading             " ;
# 		Hdg_1215:generic_name = "hdg" ;
# 		Hdg_1215:units = "degrees" ;
# 		Hdg_1215:epic_code = 1215. ;
# 		Hdg_1215:valid_range = 0., 360. ;
# 		Hdg_1215:minimum = 187.6638f ;
# 		Hdg_1215:maximum = 189.4064f ;
# 		Hdg_1215:sensor_type = "TRDI V" ;
# 		Hdg_1215:sensor_depth = 11.4440029710665 ;
# 		Hdg_1215:initial_sensor_height = 2.4 ;
# 		Hdg_1215:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Hdg_1215:height_depth_units = "m" ;
# 		Hdg_1215:serial_number = 23881. ;
# 		Hdg_1215:_FillValue = 1.e+35f ;
# 	float Ptch_1216(time, lat, lon) ;
# 		Ptch_1216:units = "degrees" ;
# 		Ptch_1216:long_name = "INST Pitch" ;
# 		Ptch_1216:epic_code = 1216. ;
# 		Ptch_1216:valid_range = -20., 20. ;
# 		Ptch_1216:minimum = -0.5267279f ;
# 		Ptch_1216:maximum = -0.1486675f ;
# 		Ptch_1216:sensor_type = "TRDI V" ;
# 		Ptch_1216:sensor_depth = 11.4440029710665 ;
# 		Ptch_1216:initial_sensor_height = 2.4 ;
# 		Ptch_1216:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Ptch_1216:height_depth_units = "m" ;
# 		Ptch_1216:serial_number = 23881. ;
# 		Ptch_1216:_FillValue = 1.e+35f ;
# 	float Roll_1217(time, lat, lon) ;
# 		Roll_1217:units = "degrees" ;
# 		Roll_1217:long_name = "INST Roll" ;
# 		Roll_1217:epic_code = 1217. ;
# 		Roll_1217:valid_range = -20., 20. ;
# 		Roll_1217:minimum = -0.9340734f ;
# 		Roll_1217:maximum = -0.3725f ;
# 		Roll_1217:sensor_type = "TRDI V" ;
# 		Roll_1217:sensor_depth = 11.4440029710665 ;
# 		Roll_1217:initial_sensor_height = 2.4 ;
# 		Roll_1217:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Roll_1217:height_depth_units = "m" ;
# 		Roll_1217:serial_number = 23881. ;
# 		Roll_1217:_FillValue = 1.e+35f ;
# 	float P_1(time, lat, lon) ;
# 		P_1:units = "dbar" ;
# 		P_1:type = "EVEN" ;
# 		P_1:epic_code = 1. ;
# 		P_1:name = "P" ;
# 		P_1:long_name = "PRESSURE (DB)          " ;
# 		P_1:generic_name = "depth" ;
# 		P_1:valid_range = 0., 10000. ;
# 		P_1:minimum = 10.77422f ;
# 		P_1:maximum = 12.4074f ;
# 		P_1:sensor_type = "TRDI V" ;
# 		P_1:sensor_depth = 11.4440029710665 ;
# 		P_1:initial_sensor_height = 2.4 ;
# 		P_1:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		P_1:height_depth_units = "m" ;
# 		P_1:serial_number = 23881. ;
# 		P_1:_FillValue = 1.e+35f ;
# 	int Or(time, lat, lon) ;
# 		Or:units = "boolean" ;
# 		Or:name = "Or" ;
# 		Or:long_name = "ORIENATION 1=UP, 0=DOWN" ;
# 		Or:generic_name = "orientation" ;
# 		Or:valid_range = 0., 1. ;
# 		Or:minimum = 1 ;
# 		Or:maximum = 1 ;
# 		Or:sensor_type = "TRDI V" ;
# 		Or:sensor_depth = 11.4440029710665 ;
# 		Or:initial_sensor_height = 2.4 ;
# 		Or:initial_sensor_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		Or:height_depth_units = "m" ;
# 		Or:serial_number = 23881. ;
# 		Or:_FillValue = -32768 ;
# 	float VDD1(time, lat, lon) ;
# 		VDD1:units = "volts" ;
# 		VDD1:long_name = "battery voltage 1" ;
# 		VDD1:minimum = 15.56866f ;
# 		VDD1:maximum = 17.38464f ;
#
# // global attributes:
# 		:SciPi = "C.Sherwood" ;
# 		:PROJECT = "USGS Coastal Marine Geology Program" ;
# 		:EXPERIMENT = "MVCO 2015 Stress Comparison" ;
# 		:DESCRIPTION = "Quadpod 13.9m" ;
# 		:DATA_SUBTYPE = "MOORED" ;
# 		:COORD_SYSTEM = "GEOGRAPHIC" ;
# 		:Conventions = "PMEL/EPIC" ;
# 		:MOORING = "1057" ;
# 		:WATER_DEPTH = 13.8440029710665 ;
# 		:WATER_DEPTH_NOTE = "(meters), nominal" ;
# 		:WATER_DEPTH_source = "water depth = MSL from pressure sensor" ;
# 		:latitude = 41.3336633 ;
# 		:longitude = -70.565877 ;
# 		:magnetic_variation = -14.7 ;
# 		:Deployment_date = "17-Nov-2015" ;
# 		:Recovery_date = "14-Dec-2015" ;
# 		:DATA_CMNT = "" ;
# 		:platform_type = "USGS aluminum T14 quadpod" ;
# 		:DRIFTER = 0. ;
# 		:POS_CONST = 0. ;
# 		:DEPTH_CONST = 0. ;
# 		:institution = "United States Geological Survey, Woods Hole Coastal and Marine Science Center" ;
# 		:institution_url = "http://woodshole.er.usgs.gov" ;
# 		:WATER_DEPTH_datum = "MSL" ;
# 		:VAR_FILL = 1.e+35 ;
# 		:INST_TYPE = "TRDI V" ;
# 		:history = "Trimmed using trunc_cdfNative,  SVN $Revision: 5793 $ to select records in the range 2 to 1295.  :Workhorse V data processed by TRDI Velocity software" ;
# 		:start_time = "17-Nov-2015 17:00:08" ;
# 		:stop_time = "14-Dec-2015 15:10:08" ;
# 		:DELTA_T = 1799. ;
# 		:latitude_units = "degree_north" ;
# 		:longitude_units = "degree_east" ;
# 		:bin_size = 0.3 ;
# 		:bin_count = 66. ;
# 		:transducer_offset_from_bottom = 2.4 ;
# 		:center_first_bin = 0.84 ;
# 		:blanking_distance = 0.4 ;
# 		:orientation = "UP" ;
# 		:orientation_note = "deployed orientation given by user" ;
# 		:nominal_instrument_depth = 11.4440029710665 ;
# 		:initial_instrument_height = 2.4 ;
# 		:depth_note = "uplooking bin depths = gatt.WATER_DEPTH-gatt.transducer_offset_from_bottom-bindist" ;
# 		:CREATION_DATE = "09-Dec-2016 11:01:23" ;
# 		:initial_instrument_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		:nominal_sensor_depth = 11.4440029710665 ;
# 		:nominal_sensor_depth_note = "inst_depth = (water_depth - inst_height); nominal depth below surface, meters" ;
# 		:serial_number = "23881" ;
# 		:transform = "EARTH" ;
# 		:DATA_TYPE = "ADCP" ;
# 		:magnetic_variation_at_site = -14.7 ;
# 		:magnetic_variation_applied = -14.7 ;
# 		:magnetic_variation_applied_note = "as stated by user, not provided by Velcoity processing" ;
# 		:beam_angle = 25. ;
# 		:FILL_FLAG = 0. ;
# 		:COMPOSITE = 0. ;
# 		:VAR_DESC = "bindist:u_1205:v_1206:w_1204:Werr_1201:Wvert:AGC_1202:AGCvert:cor:corvert:PGd_1203:Tx_1211:SV_80:Hdg_1215:Ptch_1216:Roll_1217:P_1:Or:VDD1" ;
# 		:DODS_EXTRA.Unlimited_Dimension = "time" ;
# }

# %%
# !ncdump -h http://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whVp-cal.nc
    # missing attribute serial_number
# Out:
# netcdf \10631whVp-cal {
# dimensions:
# 	time = UNLIMITED ; // (2393 currently)
# 	direction = 360 ;
# 	frequency = 64 ;
# 	lat = 1 ;
# 	lon = 1 ;
# variables:
# 	int time(time) ;
# 		time:FORTRAN_format = "F10.2" ;
# 		time:units = "True Julian Day" ;
# 		time:type = "UNEVEN" ;
# 		time:epic_code = 624 ;
# 		time:datum = "Time (UTC) in True Julian Days: 2440000 = 0000 h on May 23, 1968" ;
# 		time:NOTE = "Decimal Julian day [days] = time [days] + ( time2 [msec] / 86400000 [msec/day] )" ;
# 	int time2(time) ;
# 		time2:FORTRAN_format = "F10.2" ;
# 		time2:units = "msec since 0:00 GMT" ;
# 		time2:type = "UNEVEN" ;
# 		time2:epic_code = 624 ;
# 		time2:datum = "Time (UTC) in True Julian Days: 2440000 = 0000 h on May 23, 1968" ;
# 		time2:NOTE = "Decimal Julian day [days] = time [days] + ( time2 [msec] / 86400000 [msec/day] )" ;
# 	int burst(time) ;
# 		burst:FORTRAN_format = "F10.2" ;
# 		burst:units = "count" ;
# 		burst:generic_name = "record" ;
# 		burst:long_name = "Burst Number" ;
# 		burst:_FillValue = -2147483648 ;
# 	float lat(lat) ;
# 		lat:FORTRAN_format = "F10.2" ;
# 		lat:units = "degree_north" ;
# 		lat:type = "EVEN" ;
# 		lat:epic_code = 500 ;
# 		lat:name = "LAT" ;
# 		lat:long_name = "LATITUDE" ;
# 		lat:generic_name = "lat" ;
# 		lat:datum = "NAD83" ;
# 	float lon(lon) ;
# 		lon:FORTRAN_format = "f10.4" ;
# 		lon:units = "degree_east" ;
# 		lon:type = "EVEN" ;
# 		lon:epic_code = 502 ;
# 		lon:name = "LON" ;
# 		lon:long_name = "LONGITUDE" ;
# 		lon:generic_name = "lon" ;
# 		lon:datum = "NAD83" ;
# 	double frequency(frequency) ;
# 		frequency:name = "freq" ;
# 		frequency:long_name = "Frequency (Hz)" ;
# 		frequency:generic_name = "frequency" ;
# 		frequency:units = "Hz" ;
# 		frequency:type = "EVEN" ;
# 		frequency:FORTRAN_format = "F10.2" ;
# 		frequency:NOTE = "frequency at the center of each frequency band" ;
# 		frequency:minimum = 0.0078125 ;
# 		frequency:maximum = 0.9921875 ;
# 		frequency:sensor_type = "RD Instruments ADCP" ;
# 		frequency:sensor_depth = NaNf ;
# 		frequency:initial_sensor_height = 0.9f ;
# 		frequency:height_depth_units = "m" ;
# 		frequency:serial_number = 20784. ;
# 		frequency:band_width = 0.015625f ;
# 		frequency:band_width_units = "Hz" ;
# 		frequency:bandwidth = 0.015625f ;
# 	double direction(direction) ;
# 		direction:name = "dir" ;
# 		direction:long_name = "Direction (degrees)" ;
# 		direction:generic_name = "direction" ;
# 		direction:units = "degrees" ;
# 		direction:type = "EVEN" ;
# 		direction:FORTRAN_format = "F10.2" ;
# 		direction:NOTE = "direction at center of each direction slice" ;
# 		direction:minimum = 0. ;
# 		direction:maximum = 359. ;
# 		direction:sensor_type = "RD Instruments ADCP" ;
# 		direction:sensor_depth = NaNf ;
# 		direction:initial_sensor_height = 0.9f ;
# 		direction:height_depth_units = "m" ;
# 		direction:serial_number = 20784. ;
# 	short dspecfirstdir(time) ;
# 		dspecfirstdir:name = "dspecfirstdir" ;
# 		dspecfirstdir:long_name = "beginning of first direction slice, degrees" ;
# 		dspecfirstdir:generic_name = "directional spectrum first direction" ;
# 		dspecfirstdir:units = "degrees" ;
# 		dspecfirstdir:FORTRAN_format = "F10.2" ;
# 		dspecfirstdir:_FillValue = -32768s ;
# 		dspecfirstdir:minimum = 0s ;
# 		dspecfirstdir:maximum = 0s ;
# 		dspecfirstdir:sensor_type = "RD Instruments ADCP" ;
# 		dspecfirstdir:sensor_depth = 12.1f ;
# 		dspecfirstdir:initial_sensor_height = 0.9 ;
# 		dspecfirstdir:height_depth_units = "m" ;
# 		dspecfirstdir:serial_number = 20784. ;
# 	double wh_4061(time, lat, lon) ;
# 		wh_4061:long_name = "Significant Wave Height (m)" ;
# 		wh_4061:name = "wh" ;
# 		wh_4061:generic_name = "wave_height" ;
# 		wh_4061:units = "m" ;
# 		wh_4061:epic_code = 4061 ;
# 		wh_4061:FORTRAN_format = "F10.2" ;
# 		wh_4061:_FillValue = 1.e+35 ;
# 		wh_4061:minimum = 0.01 ;
# 		wh_4061:maximum = 2.71 ;
# 		wh_4061:valid_range = 0., 100. ;
# 		wh_4061:sensor_type = "RD Instruments ADCP" ;
# 		wh_4061:sensor_depth = 12.1f ;
# 		wh_4061:initial_sensor_height = 0.9 ;
# 		wh_4061:height_depth_units = "m" ;
# 		wh_4061:serial_number = 20784. ;
# 	double wp_4060(time, lat, lon) ;
# 		wp_4060:long_name = "Mean Wave Period (s)" ;
# 		wp_4060:name = "wp" ;
# 		wp_4060:generic_name = "wave_period" ;
# 		wp_4060:units = "s" ;
# 		wp_4060:epic_code = 4060 ;
# 		wp_4060:FORTRAN_format = "F10.2" ;
# 		wp_4060:_FillValue = 1.e+35 ;
# 		wp_4060:minimum = 1.6 ;
# 		wp_4060:maximum = 17.9 ;
# 		wp_4060:valid_range = 0., 100. ;
# 		wp_4060:sensor_type = "RD Instruments ADCP" ;
# 		wp_4060:sensor_depth = 12.1f ;
# 		wp_4060:initial_sensor_height = 0.9 ;
# 		wp_4060:height_depth_units = "m" ;
# 		wp_4060:serial_number = 20784. ;
# 	double mwh_4064(time, lat, lon) ;
# 		mwh_4064:long_name = "Maximum Wave Height (m)" ;
# 		mwh_4064:name = "mwh" ;
# 		mwh_4064:generic_name = "wave_height" ;
# 		mwh_4064:units = "m" ;
# 		mwh_4064:epic_code = 4064 ;
# 		mwh_4064:FORTRAN_format = "F10.2" ;
# 		mwh_4064:_FillValue = 1.e+35 ;
# 		mwh_4064:minimum = 0.07 ;
# 		mwh_4064:maximum = 1.e+35 ;
# 		mwh_4064:sensor_type = "RD Instruments ADCP" ;
# 		mwh_4064:sensor_depth = 12.1f ;
# 		mwh_4064:initial_sensor_height = 0.9 ;
# 		mwh_4064:height_depth_units = "m" ;
# 		mwh_4064:serial_number = 20784. ;
# 	double hght_18(time, lat, lon) ;
# 		hght_18:long_name = "Height of the Sea Surface (m)" ;
# 		hght_18:name = "hght" ;
# 		hght_18:generic_name = "height" ;
# 		hght_18:units = "m" ;
# 		hght_18:epic_code = 18 ;
# 		hght_18:FORTRAN_format = "F10.2" ;
# 		hght_18:NOTE = "height of sea surface relative to sensor" ;
# 		hght_18:_FillValue = 1.e+35 ;
# 		hght_18:minimum = 8.866 ;
# 		hght_18:maximum = 13.385 ;
# 		hght_18:valid_range = 0., 1000. ;
# 		hght_18:sensor_type = "RD Instruments ADCP" ;
# 		hght_18:sensor_depth = 12.1f ;
# 		hght_18:initial_sensor_height = 0.9 ;
# 		hght_18:height_depth_units = "m" ;
# 		hght_18:serial_number = 20784. ;
# 	double wp_peak(time, lat, lon) ;
# 		wp_peak:long_name = "Peak Wave Period (s)" ;
# 		wp_peak:name = "wp_peak" ;
# 		wp_peak:generic_name = "wave_period" ;
# 		wp_peak:units = "s" ;
# 		wp_peak:epic_code = 4063 ;
# 		wp_peak:FORTRAN_format = "F10.2" ;
# 		wp_peak:_FillValue = 1.e+35 ;
# 		wp_peak:minimum = 1.3 ;
# 		wp_peak:maximum = 18.3 ;
# 		wp_peak:valid_range = 0., 100. ;
# 		wp_peak:sensor_type = "RD Instruments ADCP" ;
# 		wp_peak:sensor_depth = 12.1f ;
# 		wp_peak:initial_sensor_height = 0.9 ;
# 		wp_peak:height_depth_units = "m" ;
# 		wp_peak:serial_number = 20784. ;
# 	double wvdir(time, lat, lon) ;
# 		wvdir:long_name = "Peak Wave Direction (degrees North)" ;
# 		wvdir:name = "wvdir" ;
# 		wvdir:generic_name = "wave_dir" ;
# 		wvdir:units = "degrees" ;
# 		wvdir:epic_code = 4062 ;
# 		wvdir:FORTRAN_format = "F10.2" ;
# 		wvdir:NOTE = "Direction FROM which waves are propagating, measured clockwise from north" ;
# 		wvdir:_FillValue = 1.e+35 ;
# 		wvdir:minimum = 0. ;
# 		wvdir:maximum = 360. ;
# 		wvdir:valid_range = 0., 360. ;
# 		wvdir:sensor_type = "RD Instruments ADCP" ;
# 		wvdir:sensor_depth = 12.1f ;
# 		wvdir:initial_sensor_height = 0.9 ;
# 		wvdir:height_depth_units = "m" ;
# 		wvdir:serial_number = 20784. ;
# 	int dspec(time, frequency, direction, lat, lon) ;
# 		dspec:name = "dspec" ;
# 		dspec:long_name = "Directional Wave Energy Spectrum (mm^2/Hz/degree)" ;
# 		dspec:generic_name = "directional spectrum" ;
# 		dspec:units = "mm^2/Hz/degree" ;
# 		dspec:DspecBins = 9., 11., 13. ;
# 		dspec:bin_size = 0.3 ;
# 		dspec:FORTRAN_format = "F10.2" ;
# 		dspec:_FillValue = -2147483648 ;
# 		dspec:minimum = 0 ;
# 		dspec:maximum = 189929080 ;
# 		dspec:valid_range = 0., 2147483647. ;
# 		dspec:NOTE = "Use caution: all spectra are provisional." ;
# 		dspec:sensor_type = "RD Instruments ADCP" ;
# 		dspec:sensor_depth = 12.1f ;
# 		dspec:initial_sensor_height = 0.9 ;
# 		dspec:height_depth_units = "m" ;
# 		dspec:serial_number = 20784. ;
# 	int pspec(time, frequency, lat, lon) ;
# 		pspec:name = "pspec" ;
# 		pspec:long_name = "Pressure-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))" ;
# 		pspec:generic_name = "pressure spectrum" ;
# 		pspec:units = "mm/sqrt(Hz)" ;
# 		pspec:FORTRAN_format = "F10.2" ;
# 		pspec:_FillValue = -2147483648 ;
# 		pspec:minimum = -3 ;
# 		pspec:maximum = 2733 ;
# 		pspec:valid_range = 0., 2147483647. ;
# 		pspec:NOTE = "Use caution: all spectra are provisional." ;
# 		pspec:sensor_type = "RD Instruments ADCP" ;
# 		pspec:sensor_depth = 12.1f ;
# 		pspec:initial_sensor_height = 0.9 ;
# 		pspec:height_depth_units = "m" ;
# 		pspec:serial_number = 20784. ;
# 	int sspec(time, frequency, lat, lon) ;
# 		sspec:name = "sspec" ;
# 		sspec:long_name = "Surface-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))" ;
# 		sspec:generic_name = "surface spectrum" ;
# 		sspec:units = "mm/sqrt(Hz)" ;
# 		sspec:FORTRAN_format = "F10.2" ;
# 		sspec:_FillValue = -2147483648 ;
# 		sspec:minimum = -59 ;
# 		sspec:maximum = 2796 ;
# 		sspec:valid_range = 0., 2147483647. ;
# 		sspec:NOTE = "Use caution: all spectra are provisional." ;
# 		sspec:sensor_type = "RD Instruments ADCP" ;
# 		sspec:sensor_depth = 12.1f ;
# 		sspec:initial_sensor_height = 0.9 ;
# 		sspec:height_depth_units = "m" ;
# 		sspec:serial_number = 20784. ;
# 	int vspec(time, frequency, lat, lon) ;
# 		vspec:name = "vspec" ;
# 		vspec:long_name = "Velocity-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))" ;
# 		vspec:generic_name = "velocity spectrum" ;
# 		vspec:units = "mm/sqrt(Hz)" ;
# 		vspec:VspecBins = -4. ;
# 		vspec:bin_size = 0.3 ;
# 		vspec:FORTRAN_format = "F10.2" ;
# 		vspec:minimum = -56 ;
# 		vspec:maximum = 2776 ;
# 		vspec:valid_range = 0., 2147483647. ;
# 		vspec:NOTE = "Use caution: all spectra are provisional." ;
# 		vspec:sensor_type = "RD Instruments ADCP" ;
# 		vspec:sensor_depth = 12.1f ;
# 		vspec:initial_sensor_height = 0.9 ;
# 		vspec:height_depth_units = "m" ;
# 		vspec:serial_number = 20784. ;
#
# // global attributes:
# 		:outFileRoot = "10631whV" ;
# 		:MOORING = "1063" ;
# 		:Deployment_date = "10-Feb-2016" ;
# 		:Recovery_date = "20-May-2016" ;
# 		:DATA_ORIGIN = "USGS WHCMSC Sediment Transport Group" ;
# 		:WATER_DEPTH = 13. ;
# 		:WATER_DEPTH_datum = "Mooring Log" ;
# 		:EXPERIMENT = "Sandwich Town Neck Beach" ;
# 		:PROJECT = "USGS Coastal Marine Geology Program" ;
# 		:DESCRIPT = "Nanopod off beach" ;
# 		:DATA_CMNT = "" ;
# 		:SciPi = "C.Sherwood" ;
# 		:latitudes = 41.7731 ;
# 		:longitude = -70.4758 ;
# 		:magnetic_variation_at_site = -14.83 ;
# 		:magnetic_variation_applied = -14.83 ;
# 		:ADCP_serial_number = 20784. ;
# 		:ADCPBinSize = 0.3 ;
# 		:wavesmon_version = "Velocity 1.5 Build 21.0 Release Date 08/07/2015, Wavesmon 4.05" ;
# 		:wavesmon_isV = "yes" ;
# 		:metafile_name = "do10631waves" ;
# 		:metafile_author = "Martini" ;
# 		:metafile_version = 0. ;
# 		:logfilename = "V10631_LogData.000" ;
# 		:CREATION_DATE = "03-Jun-2016 10:41:54" ;
# 		:INST_TYPE = "RD Instruments ADCP" ;
# 		:WATER_DEPTH_source = "unknown" ;
# 		:DATA_TYPE = "WAVESPEC" ;
# 		:DATA_SUBTYPE = "MOORED" ;
# 		:COORD_SYSTEM = "GEOGRAPHIC + sample" ;
# 		:WATER_MASS = "?" ;
# 		:POS_CONST = 0. ;
# 		:DEPTH_CONST = 0. ;
# 		:DRIFTER = 0. ;
# 		:VAR_FILL = 1.e+35 ;
# 		:FILL_FLAG = 1. ;
# 		:COMPOSITE = 0. ;
# 		:platform_type = "unknown" ;
# 		:history = "Trimmed using trunc_cdfNative,  SVN $Revision: 3342 $ to select records in the range 22 to 2414.  :Wave energy spectra converted to NetCDF by rw_adcpWvs_spec vSVN $Revision: 1449 $ on 03-Jun-2016 09:31:40; Statistical wave parameters converted to NetCDF by adcpWvs2nc:ncwrite_adcpWvs.m V 1.3 on 03-Jun-2016 09:27:15; ADCP wave data processed with RDI WavesMon software" ;
# 		:latitude = 0. ;
# 		:latitude_units = "degree_north" ;
# 		:longitude_units = "degree_east" ;
# 		:modification_date = "03-Jun-2016 09:26:35" ;
# 		:initial_instrument_height = 0.9f ;
# 		:initial_instrument_height_note = "height in meters above bottom: accurate for tripod mounted instruments" ;
# 		:nominal_sensor_depth = NaNf ;
# 		:nominal_sensor_depth_note = "inst_depth = (water_depth - inst_height); nominal depth below surface, meters" ;
# 		:WavesMonCfg.FileOK = "TRUE" ;
# 		:WavesMonCfg.ErrorLogging = "TRUE" ;
# 		:WavesMonCfg.Auto_Configure = 0. ;
# 		:WavesMonCfg.InPath = "" ;
# 		:WavesMonCfg.InFile = "MyRawData.000" ;
# 		:WavesMonCfg.Velocity_Text_File = "" ;
# 		:WavesMonCfg.OutPath = "C:\\data\\Sandwich\\10631_V20784\\waves\\" ;
# 		:WavesMonCfg.OutFile = "C:\\data\\Sandwich\\10631_V20784\\waves\\V10631_ProcWvsData_005.wvs" ;
# 		:WavesMonCfg.Skip = 0. ;
# 		:WavesMonCfg.NBursts = 0. ;
# 		:WavesMonCfg.Mode = 1. ;
# 		:WavesMonCfg.MaxFSize = 50000. ;
# 		:WavesMonCfg.HoursHist = 48. ;
# 		:WavesMonCfg.NRecordsHist = 30. ;
# 		:WavesMonCfg.HWarnLevel = 3. ;
# 		:WavesMonCfg.HDangerLevel = 6. ;
# 		:WavesMonCfg.TpWarnLevel = 18. ;
# 		:WavesMonCfg.TpDangerLevel = 22. ;
# 		:WavesMonCfg.HsScale = 0.001 ;
# 		:WavesMonCfg.EScale = 1.e-05 ;
# 		:WavesMonCfg.SIUnits = 1. ;
# 		:WavesMonCfg.Expect_Wave_Packets = "FALSE" ;
# 		:WavesMonCfg.Display_Hs_Time_Series = 1. ;
# 		:WavesMonCfg.Display_Tp_Time_Series = 1. ;
# 		:WavesMonCfg.Display_Dp_Time_Series = 1. ;
# 		:WavesMonCfg.Display_WL_Time_Series = 1. ;
# 		:WavesMonCfg.Display_Directional_Spectra = 1. ;
# 		:WavesMonCfg.Display_Surface_Spectra = 1. ;
# 		:WavesMonCfg.Display_Velocity_Spectra = 1. ;
# 		:WavesMonCfg.Display_Pressure_Spectra = 1. ;
# 		:WavesMonCfg.Display_Wave_Height_Spectra_Plot = 1. ;
# 		:WavesMonCfg.Batch_File_to_run_after_waves_processing = "" ;
# 		:WavesMonCfg.VelTimeSeries = 1. ;
# 		:WavesMonCfg.IntTimeSeries = 0. ;
# 		:WavesMonCfg.SurfTimeSeries = 1. ;
# 		:WavesMonCfg.PressTimeSeries = 1. ;
# 		:WavesMonCfg.VelSpectra = 1. ;
# 		:WavesMonCfg.SurfSpectra = 1. ;
# 		:WavesMonCfg.PressSpectra = 1. ;
# 		:WavesMonCfg.DirSpectra = 1. ;
# 		:WavesMonCfg.SurfaceDirSpectra = 0. ;
# 		:WavesMonCfg.WaveParams = 1. ;
# 		:WavesMonCfg.Process_VelTimeSeries = 1. ;
# 		:WavesMonCfg.Process_IntTimeSeries = 0. ;
# 		:WavesMonCfg.Process_SurfTimeSeries = 1. ;
# 		:WavesMonCfg.Process_PressTimeSeries = 1. ;
# 		:WavesMonCfg.Process_VelSpectra = 1. ;
# 		:WavesMonCfg.Process_SurfSpectra = 1. ;
# 		:WavesMonCfg.Process_PressSpectra = 1. ;
# 		:WavesMonCfg.Process_DirSpectra = 1. ;
# 		:WavesMonCfg.Process_SurfDirSpectra = 0. ;
# 		:WavesMonCfg.Process_WaveParams = 1. ;
# 		:WavesMonCfg.Process_HPR_Series = 1. ;
# 		:WavesMonCfg.DumpText = 1. ;
# 		:WavesMonCfg.SaveBin = 1. ;
# 		:WavesMonCfg.ShowE = 0. ;
# 		:WavesMonCfg.NDataTypes = 9. ;
# 		:WavesMonCfg.EPB = 2048. ;
# 		:WavesMonCfg.TBE = 50. ;
# 		:WavesMonCfg.TBB = 3600. ;
# 		:WavesMonCfg.BeamConf = 20. ;
# 		:WavesMonCfg.NomDepth = 0. ;
# 		:WavesMonCfg.XdcrAlt = 90. ;
# 		:WavesMonCfg.SOS = 0. ;
# 		:WavesMonCfg.DepthOffset = 0. ;
# 		:WavesMonCfg.DepthScale = 1. ;
# 		:WavesMonCfg.AltOffset = 0. ;
# 		:WavesMonCfg.NominalHeading = 0. ;
# 		:WavesMonCfg.HeadingOffset = -14. ;
# 		:WavesMonCfg.ApplyMagVar = "TRUE" ;
# 		:WavesMonCfg.StartTime = "" ;
# 		:WavesMonCfg.NBeams = 4. ;
# 		:WavesMonCfg.Horizontal_Setup_Type = 0. ;
# 		:WavesMonCfg.Downward_Setup_Type = 0. ;
# 		:WavesMonCfg.ADCP_Coordinate_System = 3. ;
# 		:WavesMonCfg.VelMin = -5000. ;
# 		:WavesMonCfg.Bottom_Slope_X_axis = 0. ;
# 		:WavesMonCfg.Bottom_Slope_Y_axis = 0. ;
# 		:WavesMonCfg.VelMax = 5000. ;
# 		:WavesMonCfg.VelSTD = 4. ;
# 		:WavesMonCfg.VelMaxChng = 150. ;
# 		:WavesMonCfg.VelPctGd = 90. ;
# 		:WavesMonCfg.SurfMin = 5250. ;
# 		:WavesMonCfg.SurfMax = 100000. ;
# 		:WavesMonCfg.SurfSTD = 4. ;
# 		:WavesMonCfg.SurfMaxChng = 2000. ;
# 		:WavesMonCfg.SurfPctGd = 90. ;
# 		:WavesMonCfg.Surf_Peak_Amplitude_Threshold = 20. ;
# 		:WavesMonCfg.Surfacetrack_Max_Search_Range = 0. ;
# 		:WavesMonCfg.Surfacetrack_Using_Search_Window_defined_by_pressure_sensor = 1. ;
# 		:WavesMonCfg.TBEMaxDev = 500. ;
# 		:WavesMonCfg.HMaxDev = 5. ;
# 		:WavesMonCfg.PRMaxDev = 5. ;
# 		:WavesMonCfg.Small_Wave_Freq = 80. ;
# 		:WavesMonCfg.Small_Wave_Thresh = 0. ;
# 		:WavesMonCfg.Fix_SOS = 0. ;
# 		:WavesMonCfg.Screen_Direction_Start = -1. ;
# 		:WavesMonCfg.Screen_Direction_Stop = -1. ;
# 		:WavesMonCfg.Min_SNR_in_std_for_spectra = 4. ;
# 		:WavesMonCfg.extrapolate_unmeasured_spectrum = 1. ;
# 		:WavesMonCfg.Infra-Gravity_Wave_Setup = 0. ;
# 		:WavesMonCfg.Sea-Swell_Transition_Period = 8. ;
# 		:WavesMonCfg.Low_Correlation_Threshold = 64. ;
# 		:WavesMonCfg.Fish_Amplitude_Threshold = 50. ;
# 		:WavesMonCfg.Error_Velocity_Threshold = 2000. ;
# 		:WavesMonCfg.Bin_Mapping = 1. ;
# 		:WavesMonCfg.Bin_Mapping_Beam_5 = 1. ;
# 		:WavesMonCfg.Coordinate_Transform_Beam_5 = 1. ;
# 		:WavesMonCfg.Ping1_Ping2_averaging_compatibility = 1. ;
# 		:WavesMonCfg.High_Correlation_Threshold = 0. ;
# 		:WavesMonCfg.NFreqBins = 64. ;
# 		:WavesMonCfg.NDir = 360. ;
# 		:WavesMonCfg.FFTLen = 2048. ;
# 		:WavesMonCfg.WindowType = 1. ;
# 		:WavesMonCfg.Surf4Depth = 0. ;
# 		:WavesMonCfg.Press4Depth = 1. ;
# 		:WavesMonCfg.TransV2Surf = 1. ;
# 		:WavesMonCfg.HoldDisplay = 1. ;
# 		:WavesMonCfg.Iterations = 3. ;
# 		:WavesMonCfg.Over_Relaxation_Gain = 0.9 ;
# 		:WavesMonCfg.DummySurf = 0. ;
# 		:WavesMonCfg.SampleRate = 2. ;
# 		:WavesMonCfg.FreqThresh = 0.95 ;
# 		:WavesMonCfg.Surf_FreqThresh = 0.95 ;
# 		:WavesMonCfg.Press_FreqThresh = 0.5 ;
# 		:WavesMonCfg.LowerFreqThresh = 0.03 ;
# 		:WavesMonCfg.RemoveBias = 1. ;
# 		:WavesMonCfg.Clip_Negative_Values_to_0_in_Pwr_Spec = 0. ;
# 		:WavesMonCfg.MinPeriod = 5. ;
# 		:WavesMonCfg.MaxPeriod = 26. ;
# 		:WavesMonCfg.InvertFreqAxis = "FALSE" ;
# 		:WavesMonCfg.Correct_Waves_for_Mean_Currents = "FALSE" ;
# 		:WavesMonCfg.ScaleSpec = 4. ;
# 		:WavesMonCfg.Use_File_Buffer_Rather_Than_Memory_Buffer_if_RAM_is_Sparse = "TRUE" ;
# 		:WavesMonCfg.Simulate = 0. ;
# 		:WavesMonCfg.Simulated_Freq_Lo = 0.01 ;
# 		:WavesMonCfg.Simulated_Freq_Hi = 0.5 ;
# 		:WavesMonCfg.Simulated_Direction_1 = 45. ;
# 		:WavesMonCfg.Simulation_Type = 1. ;
# 		:WavesMonCfg.Simulated_Freq_Lo_2 = 0.3 ;
# 		:WavesMonCfg.Simulated_Freq_Hi_2 = 0.95 ;
# 		:WavesMonCfg.Simulated_Direction_2 = 270. ;
# 		:WavesMonCfg.Simulated_Direction_Spread = 5. ;
# 		:WavesMonCfg.Simulated_Direction_Spread_2 = 30. ;
# 		:WavesMonCfg.Simulated_Signal_Level = 2000. ;
# 		:WavesMonCfg.Simulated_Signal_Level2 = 2000. ;
# 		:WavesMonCfg.Simulated_Noise_Level = 1. ;
# 		:WavesMonCfg.Simulated_Depth_Cell_Size = 35. ;
# 		:WavesMonCfg.Simulated_Blanking_Dist = 200. ;
# 		:WavesMonCfg.Simulated_Sea_State_1__flat_wind_sea_swell_ = 1. ;
# 		:WavesMonCfg.Simulated_Sea_State_2__flat_wind_sea_swell_ = 2. ;
# 		:WavesMonCfg.Edit5 = 0. ;
# 		:WavesMonCfg.Edit6 = 0. ;
# 		:WavesMonCfg.Check1 = 0. ;
# 		:WavesMonCfg.Call_WaveView_To_Make_Images = 0. ;
# 		:WavesMonCfg.Do_UVW_Triplet_Processing = 0. ;
# 		:WavesMonCfg.Output_Dir_Spec_squared_in_both_Dimensioins_so_integrated_dir_e = 1. ;
# 		:WavesMonCfg.Modeling_Assumptions_Used_for_Trieplet_Processing = 1. ;
# 		:WavesMonCfg.VSpec_Offset = 0. ;
# 		:WavesMonCfg.SSpec_Offset = 0. ;
# 		:WavesMonCfg.PSpec_Offset = 0. ;
# 		:WavesMonCfg.WaveParamSource = "B" ;
# 		:WavesMonCfg.Screen_this_Spectrum_First_if_they_do_not_compare = "S" ;
# 		:WavesMonCfg.Auto_Bin_Selection = 1. ;
# 		:WavesMonCfg.Calibrate_Pressure_Sensor_Average_Depth_Using_Surface_Track_Avg = "FALSE" ;
# 		:WavesMonCfg.Freq_Bands_for_Directional_Spectrum = 64. ;
# 		:WavesMonCfg.Correct_for_Tilted_Orientation = 0. ;
# 		:WavesMonCfg.Fixed_Pitch = 0. ;
# 		:WavesMonCfg.Fixed_Roll = 0. ;
# 		:WavesMonCfg.VelTSBins = "" ;
# 		:WavesMonCfg.IntTSBins = "" ;
# 		:WavesMonCfg.VSpecBins = -4. ;
# 		:WavesMonCfg.DirSpecBins = 9., 11., 13. ;
# 		:VAR_DESC = ":wh:wp:mwh:hght:wp_peak:wvdir:dspec:dspecfirstdir:pspec:sspec:vspec" ;
# 		:WavesMonCfg.LogDataFile = "V10631_LogData.000" ;
# 		:start_time = "10-Feb-2016 18:59:59" ;
# 		:stop_time = "20-May-2016 14:00:00" ;
# 		:DELTA_T = 3605. ;
# 		:DODS_EXTRA.Unlimited_Dimension = "time" ;
# }

# %%
#
fn='https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'
# it looks like casting to a string works for the MVCO file but not the Sandwhich one...
fnc=nc.Dataset(str(fn),mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
all_atts=fnc.__dict__  # get all the global atts and their values as a dict
all_atts
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-d0d3032fdd8c> in <module>
#       2 fn='https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'
#       3 # it looks like casting to a string works for the MVCO file but not the Sandwhich one...
# ----> 4 fnc=nc.Dataset(str(fn),mode='r+',format='NETCDF3_CLASSIC') # don't use 'w' will delete existing file!
#       5 all_atts=fnc.__dict__  # get all the global atts and their values as a dict
#       6 all_atts
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -36] NetCDF: Invalid argument: b'https://stellwagen.er.usgs.gov/thredds/dodsC/TSdata/SANDWICH2016/10631whV-cal.nc'

# %%
print('mooring ', all_atts['MOORING'],': there is a ', all_atts['INST_TYPE'],'; SN ',all_atts['serial_number'])
fnc.close()
