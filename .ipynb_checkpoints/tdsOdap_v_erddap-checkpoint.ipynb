# %%
import xarray as xr
import netCDF4 as nc

# %% [markdown]
# Compares the structure of ERDDAP tableDAP to TDS OPeNDAP;
# Xarray reads both, but the content organization is different.
#
# Also compares what xarray gets to what netCDF4 package gets.

# %%
nc.Dataset('https://gamone.whoi.edu/erddap/tabledap/10181Aysi-a')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     cdm_data_type: TimeSeries
#     cdm_timeseries_variables: latitude, longitude, altitude, feature_type_instance
#     COMPOSITE: 0.0
#     contributor_name: N. Ganju
#     contributor_role: principalInvestigator
#     Conventions: CF-1.6,ACDD-1.3, COARDS
#     COORD_SYSTEM: GEOGRAPHIC
#     CREATION_DATE: 16-Mar-2016 16:52:04
#     creator_email: rsignell@usgs.gov
#     creator_name: Rich Signell
#     creator_phone: +1 (508) 548-8700
#     creator_url: https://www.usgs.gov
#     DATA_ORIGIN: USGS WHCMSC Sed Trans Group
#     DATA_SUBTYPE: MOORED
#     date_created: 2017-04-11T21:31:00Z
#     date_issued: 2017-04-11T21:31:00Z
#     date_metadata_modified: 2017-04-11T21:31:00Z
#     date_modified: 2017-04-11T21:31:00Z
#     DELTA_T: 900.0
#     Deployment_date: 15-Aug-2014
#     DEPTH_CONST: 0.0
#     DESCRIPTION: site CB01, Tom's Cove on old USCG pier
#     DRIFTER: 0.0
# ...

# %%
xr.open_dataset('https://gamone.whoi.edu/erddap/tabledap/10181Aysi-a', decode_times=False)
# Out:
# <xarray.Dataset>
# Dimensions:                  (s: 5976)
# Dimensions without coordinates: s
# Data variables:
#     s.DO                     (s) float64 ...
#     s.crs                    (s) int32 ...
#     s.SpC_48                 (s) float64 ...
#     s.OST_62                 (s) float64 ...
#     s.dn                     (s) float64 ...
#     s.feature_type_instance  (s) |S64 ...
#     s.latitude               (s) float64 ...
#     s.C_51                   (s) float64 ...
#     s.altitude               (s) float64 ...
#     s.S_40                   (s) float64 ...
#     s.P_1ac                  (s) float64 ...
#     s.time                   (s) float64 ...
#     s.D_3                    (s) float64 ...
#     s.platform               (s) int32 ...
#     s.Turb                   (s) float64 ...
#     s.longitude              (s) float64 ...
#     s.T_28                   (s) float64 ...
#     s.BPR_1301               (s) float64 ...
# Attributes:
# ...

# %%
nc.Dataset('http://gamone.whoi.edu/thredds/dodsC/silt/usgs/Projects/stellwagen/CF-1.6/CHINCOTEAGUE/10181Aysi-a.nc')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     creator_email: rsignell@usgs.gov
#     id: 10181Aysi-a
#     WATER_DEPTH: 1.9
#     publisher_phone: +1 (508) 548-8700
#     history: Remove obvious spikes/bad data, Trimmed using trunc_cdfNative,  SVN $Revision: 3342 $ to select records in the range 433 to 6408.  :created using ysi2ncNative in Matlab 7.14.0.739 (R2012a).
# 2017-04-11T21:31:00Z - pyaxiom - File created using pyaxiom
#     DRIFTER: 0.0
#     creator_url: http://www.usgs.gov
#     initial_instrument_height: 0.5
#     project_title:  Estuarine Physical Response to Storms (EPR), Chincoteague Bay, Maryland/Virginia, 2014-2015
#     magnetic_variation: -11.58
#     DEPTH_CONST: 0.0
#     COORD_SYSTEM: GEOGRAPHIC
#     keywords: Oceans > Ocean Pressure > Water Pressure, Oceans > Ocean Temperature > Water Temperature, Oceans > Salinity/Density > Conductivity, Oceans > Salinity/Density > Salinity
#     COMPOSITE: 0.0
# ...

# %%
xr.open_dataset('http://gamone.whoi.edu/thredds/dodsC/silt/usgs/Projects/stellwagen/CF-1.6/CHINCOTEAGUE/10181Aysi-a.nc', decode_times=False)
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 5976)
# Coordinates:
#     latitude               float64 ...
#     longitude              float64 ...
#   * time                   (time) float64 1.408e+09 1.408e+09 ... 1.413e+09
#     z                      float64 ...
# Data variables:
#     feature_type_instance  |S64 ...
#     crs                    int32 ...
#     platform               int32 ...
#     BPR_1301               (time) float64 ...
#     C_51                   (time) float64 ...
#     DO                     (time) float64 ...
#     D_3                    (time) float64 ...
#     OST_62                 (time) float64 ...
#     P_1ac                  (time) float64 ...
#     S_40                   (time) float64 ...
#     SpC_48                 (time) float64 ...
#     T_28                   (time) float64 ...
#     Turb                   (time) float64 ...
#     dn                     (time) float64 ...
# Attributes:
# ...
